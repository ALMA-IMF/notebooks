# %%
import sys
import numpy as np
sys.path.append('/orange/adamginsburg/ALMA_IMF/reduction/analysis')
from zoom_figures import make_zoom


import imp
import zoom_figures
imp.reload(zoom_figures)
from zoom_figures import make_zoom, make_multifig

# %%
sys.path.append('/orange/adamginsburg/ALMA_IMF/reduction/analysis')
from spectralindex import prefixes
#prefixes['W43MM1'] = dict(
#        finaliter_prefix_b3="W43-MM1/B3/cleanest/W43-MM1_B3_uid___A001_X1296_X1af_continuum_merged_12M_robust0_selfcal4_finaliter",
#        finaliter_prefix_b6="W43-MM2/B6/cleanest/W43-MM2_B6_uid___A001_X1296_X113_continuum_merged_12M_robust0_selfcal5_finaliter",)

# %%
os.chdir('/orange/adamginsburg/ALMA_IMF/2017.1.01355.L/May2021Release/')

# %%
import pylab as pl

# %%
make_multifig('G008', band='B6', nsigma_linear_max=15, inner_stretch='asinh')
# Out:
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['6.1', '9.1', '14', '20', '30', '44', '65', '97', '140', '210']
# [array(271.60390614), array(-21.633371)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (271.60390614, -21.633371)>

# %%
make_multifig('G333', band='B6', inner_stretch='asinh')
# Out:
# old ticks: <a list of 4 Text yticklabel objects>, new ticks: ['2.7', '4.5', '7.5', '12', '20', '33', '55', '90', '150', '240']
# [array(245.56395158), array(-50.11551531)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (245.56395158, -50.11551531)>

# %%
for band in ('B3','B6'):
    for fieldid in prefixes:
        print(fieldid, band)
        make_multifig(fieldid, band=band, inner_stretch='asinh')
# Out:
# G328 B3
# old ticks: <a list of 6 Text yticklabel objects>, new ticks: ['1.4', '1.8', '2.3', '3.0', '3.8', '4.8', '6.1', '7.7', '9.7', '12']
# [array(239.52863823), array(-53.98663305)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (239.52863823, -53.98663305)>
# G333 B3
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['1.9', '3.3', '5.7', '9.6', '16', '27', '46', '77', '130', '220']
# [array(245.57199139), array(-50.11969559)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (245.57199139, -50.11969559)>
# G12 B3
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['3.6', '6.7', '12', '22', '41', '75', '140', '250', '450', '830']
# [array(273.57800459), array(-17.9491278)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (273.57800459, -17.9491278)>
# W51IRS2 B3
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['1.2', '2.0', '3.3', '5.2', '8.2', '13', '20', '32', '51', '80']
# [array(290.93399386), array(14.50087006)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (290.93399386, 14.50087006)>
# G008 B3
# old ticks: <a list of 4 Text yticklabel objects>, new ticks: ['2.1', '3.3', '5.1', '7.9', '12', '18', '28', '43', '65', '99']
# [array(271.60862849), array(-21.63701087)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (271.60862849, -21.63701087)>
# G327 B3
# old ticks: <a list of 9 Text yticklabel objects>, new ticks: ['2.0', '2.7', '3.6', '4.7', '6.2', '8.1', '11', '14', '18', '24']
# [array(238.3142963), array(-54.63589411)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (238.3142963, -54.63589411)>
# G10 B3
# old ticks: <a list of 5 Text yticklabel objects>, new ticks: ['0.91', '2.0', '3.8', '7.1', '13', '25', '45', '84', '160', '290']
# [array(272.63798721), array(-19.94766012)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (272.63798721, -19.94766012)>
# G337 B3
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['1.0', '1.5', '2.1', '2.9', '3.9', '5.3', '7.1', '9.5', '13', '17']
# [array(250.32007988), array(-47.15093567)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (250.32007988, -47.15093567)>
# G338 B3
# old ticks: <a list of 5 Text yticklabel objects>, new ticks: ['1.1', '1.5', '1.9', '2.5', '3.2', '4.1', '5.3', '6.7', '8.5', '11']
# [array(250.16764906), array(-45.71227353)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (250.16764906, -45.71227353)>
# G351 B3
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['3.7', '5.3', '7.5', '11', '15', '21', '30', '43', '61', '86']
# [array(261.70391578), array(-36.17570028)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (261.70391578, -36.17570028)>
# G353 B3
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['2.8', '4.6', '7.2', '11', '18', '28', '45', '70', '110', '170']
# [array(262.6354839), array(-34.71724707)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (262.6354839, -34.71724707)>
# W43MM3 B3
# old ticks: <a list of 6 Text yticklabel objects>, new ticks: ['0.48', '0.75', '1.1', '1.4', '1.8', '2.4', '3.0', '3.8', '4.8', '6.0']
# [array(281.94538), array(-2.02768649)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (281.94538, -2.02768649)>
# W43MM2 B3
# old ticks: <a list of 6 Text yticklabel objects>, new ticks: ['0.57', '0.76', '0.97', '1.2', '1.5', '1.8', '2.1', '2.5', '3.0', '3.6']
# [array(281.92515591), array(-2.03418454)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (281.92515591, -2.03418454)>
# W43MM1 B3
# old ticks: <a list of 6 Text yticklabel objects>, new ticks: ['0.67', '1.1', '1.6', '2.2', '3.0', '4.1', '5.6', '7.6', '10', '14']
# [array(281.96855731), array(-1.92907177)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (281.96855731, -1.92907177)>
# W51-E B3
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['1.2', '2.5', '4.9', '9.2', '17', '33', '61', '110', '210', '400']
# [array(290.95223478), array(14.4914343)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (290.95223478, 14.4914343)>
# G328 B6
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['5.7', '8.3', '12', '17', '25', '36', '51', '74', '110', '150']
# [array(239.52098322), array(-53.98009395)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (239.52098322, -53.98009395)>
# G333 B6
# old ticks: <a list of 4 Text yticklabel objects>, new ticks: ['2.7', '4.5', '7.5', '12', '20', '33', '55', '90', '150', '240']
# [array(245.56395158), array(-50.11551531)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (245.56395158, -50.11551531)>
# G12 B6
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['8.2', '13', '20', '30', '46', '71', '110', '170', '260', '400']
# [array(273.57103114), array(-17.94375646)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (273.57103114, -17.94375646)>
# W51IRS2 B6
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['2.9', '5.6', '11', '20', '38', '71', '130', '250', '470', '880']
# [array(290.9264769), array(14.50678888)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (290.9264769, 14.50678888)>
# G008 B6
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['6.1', '9.1', '14', '20', '30', '44', '65', '97', '140', '210']
# [array(271.60390614), array(-21.633371)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (271.60390614, -21.633371)>
# G327 B6
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['7.0', '12', '20', '35', '59', '100', '170', '290', '490', '830']
# [array(238.30405577), array(-54.63117487)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (238.30405577, -54.63117487)>
# G10 B6
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['1.8', '3.4', '6.1', '11', '20', '36', '65', '120', '210', '380']
# [array(272.63164691), array(-19.94034675)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (272.63164691, -19.94034675)>
# G337 B6
# old ticks: <a list of 5 Text yticklabel objects>, new ticks: ['2.9', '4.9', '8.2', '14', '22', '37', '61', '100', '170', '280']
# [array(250.30934038), array(-47.14375436)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (250.30934038, -47.14375436)>
# G338 B6
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['3.4', '5.3', '8.1', '12', '19', '29', '44', '67', '100', '150']
# [array(250.15716328), array(-45.704899)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (250.15716328, -45.704899)>
# G351 B6
# old ticks: <a list of 5 Text yticklabel objects>, new ticks: ['7.2', '12', '19', '30', '49', '79', '130', '210', '330', '540']
# [array(261.69564153), array(-36.1702616)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (261.69564153, -36.1702616)>
# G353 B6
# old ticks: <a list of 5 Text yticklabel objects>, new ticks: ['6.0', '8.3', '12', '16', '22', '31', '42', '59', '81', '110']
# [array(262.62718527), array(-34.71171059)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (262.62718527, -34.71171059)>
# W43MM3 B6
# old ticks: <a list of 5 Text yticklabel objects>, new ticks: ['1.3', '2.1', '3.2', '4.9', '7.4', '11', '17', '25', '38', '56']
# [array(281.93302026), array(-2.0184636)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (281.93302026, -2.0184636)>
# W43MM2 B6
# old ticks: <a list of 7 Text yticklabel objects>, new ticks: ['2.1', '3.4', '5.6', '8.9', '14', '23', '37', '58', '93', '150']
# [array(281.91284199), array(-2.02507832)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (281.91284199, -2.02507832)>
# W43MM1 B6
# old ticks: <a list of 6 Text yticklabel objects>, new ticks: ['1.8', '3.4', '6.0', '11', '19', '34', '60', '110', '190', '330']
# [array(281.95811197), array(-1.92185994)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (281.95811197, -1.92185994)>
# W51-E B6
# old ticks: <a list of 8 Text yticklabel objects>, new ticks: ['4.1', '6.8', '11', '19', '32', '53', '88', '150', '240', '400']
# [array(290.9446997), array(14.49736221)]
# <SkyCoord (FK5: equinox=J2000.000): (ra, dec) in deg
#     (290.9446997, 14.49736221)>

# %%
cp -v /orange/adamginsburg/ALMA_IMF/datapaper/figures/*multicolor*png /orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/
# Out:
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G008_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G008_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G008_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G008_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G10_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G10_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G10_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G10_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G12_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G12_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G12_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G12_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G327_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G327_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G327_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G327_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G328_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G328_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G328_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G328_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G333_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G333_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G333_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G333_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G337_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G337_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G337_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G337_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G338_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G338_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G338_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G338_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G351_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G351_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G351_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G351_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G353_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G353_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/G353_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/G353_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W43MM1_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W43MM1_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W43MM1_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W43MM1_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W43MM2_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W43MM2_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W43MM2_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W43MM2_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W43MM3_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W43MM3_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W43MM3_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W43MM3_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W51-E_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W51-E_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W51-E_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W51-E_multicolor_B6.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W51IRS2_multicolor_B3.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W51IRS2_multicolor_B3.png’
# ‘/orange/adamginsburg/ALMA_IMF/datapaper/figures/W51IRS2_multicolor_B6.png’ -> ‘/orange/adamginsburg/web/secure/ALMA-IMF/overview_twocolorscales/W51IRS2_multicolor_B6.png’

# %%
import numpy as np, pylab as pl
from astropy.visualization import simple_norm
import matplotlib.ticker as ticker

x = np.random.randn(100,100) + 5
x[20,20] = 100
norm = simple_norm(x, stretch='asinh')
pl.imshow(x, norm=norm)
cb = pl.colorbar()
cb.ax.yaxis.set_major_locator(ticker.MaxNLocator(5))
