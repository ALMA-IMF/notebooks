# %%
# %matplotlib inline
import pylab as pl

# for display within notebook
pl.rcParams['figure.facecolor'] = 'w'

# %%
# debug
import imp
import sys
sys.path.append('/orange/adamginsburg/ALMA_IMF/reduction/analysis')
import imstats
imp.reload(imstats)
from imstats import get_psf_secondpeak

# %%
# %run /orange/adamginsburg/ALMA_IMF/reduction/analysis/psf_check_figures.py
# Out:
# INFO: G008.67 B3 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 13 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G010.62 B3 [__main__]
# INFO: first_sidelobe_ind=15, first_min_ind = 13 [imstats]
# INFO: G012.80 B3 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 12 [imstats]
# INFO: G327.29 B3 [__main__]
# INFO: first_sidelobe_ind=15, first_min_ind = 14 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G328.25 B3 [__main__]
# INFO: first_sidelobe_ind=17, first_min_ind = 16 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G333.60 B3 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 13 [imstats]
# INFO: G337.92 B3 [__main__]
# INFO: first_sidelobe_ind=22, first_min_ind = 19 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G338.93 B3 [__main__]
# INFO: first_sidelobe_ind=15, first_min_ind = 14 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G351.77 B3 [__main__]
# INFO: radial extent = 21.73913043478325,  r_max_sidelobe = 79.0602804033185, ******** [imstats]
# INFO: G353.41 B3 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 12 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: W43-MM1 B3 [__main__]
# INFO: first_sidelobe_ind=19, first_min_ind = 18 [imstats]
# INFO: W43-MM2 B3 [__main__]
# INFO: first_sidelobe_ind=10, first_min_ind = 7 [imstats]
# INFO: W43-MM3 B3 [__main__]
# INFO: first_sidelobe_ind=9, first_min_ind = 7 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: W51-E B3 [__main__]
# INFO: first_sidelobe_ind=12, first_min_ind = 10 [imstats]
# INFO: W51-IRS2 B3 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: first_sidelobe_ind=10, first_min_ind = 7 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G008.67 B6 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 13 [imstats]
# INFO: G010.62 B6 [__main__]
# INFO: first_sidelobe_ind=9, first_min_ind = 6 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G012.80 B6 [__main__]
# INFO: radial extent = 29.41176470588239,  r_max_sidelobe = 47.054264109571676, ******** [imstats]
# INFO: G327.29 B6 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 12 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G328.25 B6 [__main__]
# INFO: first_sidelobe_ind=8, first_min_ind = 7 [imstats]
# INFO: G333.60 B6 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 13 [imstats]
# INFO: G337.92 B6 [__main__]
# INFO: first_sidelobe_ind=23, first_min_ind = 22 [imstats]
# INFO: G338.93 B6 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 12 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G351.77 B6 [__main__]
# INFO: radial extent = 31.250000000000302,  r_max_sidelobe = 34.044139567088486, ******** [imstats]
# INFO: G353.41 B6 [__main__]
# INFO: radial extent = 31.250000000000302,  r_max_sidelobe = 36.51257548068336, ******** [imstats]
# INFO: W43-MM1 B6 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: radial extent = 71.42857142857251,  r_max_sidelobe = 99.07918668874281, ******** [imstats]
# INFO: W43-MM2 B6 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 9 [imstats]
# INFO: W43-MM3 B6 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: first_sidelobe_ind=8, first_min_ind = 6 [imstats]
# INFO: W51-E B6 [__main__]
# INFO: first_sidelobe_ind=17, first_min_ind = 14 [imstats]
# INFO: W51-IRS2 B6 [__main__]
# INFO: first_sidelobe_ind=10, first_min_ind = 6 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]

# %%
pl.show()

# %%
# %run /orange/adamginsburg/ALMA_IMF/reduction/analysis/psf_check_figures.py
# Out:
# INFO: G008.67 B3 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 13 [imstats]
# INFO: G010.62 B3 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: first_sidelobe_ind=15, first_min_ind = 13 [imstats]
# INFO: G012.80 B3 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 12 [imstats]
# INFO: G327.29 B3 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: first_sidelobe_ind=15, first_min_ind = 14 [imstats]
# INFO: G328.25 B3 [__main__]
# INFO: first_sidelobe_ind=17, first_min_ind = 16 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G333.60 B3 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 13 [imstats]
# INFO: G337.92 B3 [__main__]
# INFO: first_sidelobe_ind=22, first_min_ind = 19 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G338.93 B3 [__main__]
# INFO: first_sidelobe_ind=15, first_min_ind = 14 [imstats]
# INFO: G351.77 B3 [__main__]
# INFO: radial extent = 21.73913043478325,  r_max_sidelobe = 79.0602804033185, ******** [imstats]
# INFO: G353.41 B3 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 12 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: W43-MM1 B3 [__main__]
# INFO: first_sidelobe_ind=19, first_min_ind = 18 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: W43-MM2 B3 [__main__]
# INFO: first_sidelobe_ind=10, first_min_ind = 7 [imstats]
# INFO: W43-MM3 B3 [__main__]
# INFO: first_sidelobe_ind=9, first_min_ind = 7 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: W51-E B3 [__main__]
# INFO: first_sidelobe_ind=12, first_min_ind = 10 [imstats]
# INFO: W51-IRS2 B3 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: first_sidelobe_ind=10, first_min_ind = 7 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G008.67 B6 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 13 [imstats]
# INFO: G010.62 B6 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: first_sidelobe_ind=9, first_min_ind = 6 [imstats]
# INFO: G012.80 B6 [__main__]
# INFO: radial extent = 29.41176470588239,  r_max_sidelobe = 47.054264109571676, ******** [imstats]
# INFO: G327.29 B6 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 12 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G328.25 B6 [__main__]
# INFO: first_sidelobe_ind=8, first_min_ind = 7 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G333.60 B6 [__main__]
# INFO: first_sidelobe_ind=16, first_min_ind = 13 [imstats]
# INFO: G337.92 B6 [__main__]
# INFO: first_sidelobe_ind=23, first_min_ind = 22 [imstats]
# INFO: G338.93 B6 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 12 [imstats]
# INFO: G351.77 B6 [__main__]
# INFO: radial extent = 31.250000000000302,  r_max_sidelobe = 34.044139567088486, ******** [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: G353.41 B6 [__main__]
# INFO: radial extent = 31.250000000000302,  r_max_sidelobe = 36.51257548068336, ******** [imstats]
# INFO: W43-MM1 B6 [__main__]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: radial extent = 71.42857142857251,  r_max_sidelobe = 99.07918668874281, ******** [imstats]
# INFO: W43-MM2 B6 [__main__]
# INFO: first_sidelobe_ind=14, first_min_ind = 9 [imstats]
# INFO: W43-MM3 B6 [__main__]
# INFO: first_sidelobe_ind=8, first_min_ind = 6 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# INFO: W51-E B6 [__main__]
# INFO: first_sidelobe_ind=17, first_min_ind = 14 [imstats]
# INFO: W51-IRS2 B6 [__main__]
# INFO: first_sidelobe_ind=10, first_min_ind = 6 [imstats]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]

# %%
pl.show()

# %%
psf_secondpeak_loc
# Out:
# 0.8914302155809751

# %%
from scipy import ndimage
import scipy.signal

# %%
rbin = (rr).astype(np.int)
radial_mean = ndimage.mean(cutout, labels=rbin, index=np.arange(100))
radial_mean2 = ndimage.mean(cutout**2, labels=rbin, index=np.arange(100))
first_min_ind = scipy.signal.find_peaks(-radial_mean2)[0][0]
first_sidelobe_ind = scipy.signal.find_peaks(radial_mean2 *
                      (np.arange(len(radial_mean2)) > first_min_ind))[0][0]
# Out:
# /scratch/local/10336938/ipykernel_64866/555310049.py:1: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   rbin = (rr).astype(np.int)

# %%
pl.figure(figsize=(12,6))
pl.rcParams['font.size'] = 14
pl.subplot(1,2,1)
pl.plot(rr.ravel(), cutout.ravel(), '.', markersize=3)
pl.plot(radial_mean)
pl.vlines([first_min_ind, first_sidelobe_ind], -0.1,0.15, linestyle=':', color='r')
pl.plot([0,300], [0,0], 'k--')
pl.axis((0,30,-0.05,0.15))
pl.xlabel("Pixel Index")
pl.ylabel("PSF")

pl.subplot(1,2,2)
pl.plot(rr.ravel(), cutout.ravel()**2, '.', markersize=3)
pl.plot(radial_mean2)
pl.vlines([first_min_ind, first_sidelobe_ind], -0.1,0.15, linestyle=':', color='r')
pl.plot([0,300], [0,0], 'k--')
pl.axis((0,30,0.0,0.15**2))
pl.xlabel("Pixel Index")
pl.ylabel("PSF$^2$")
pl.tight_layout()
# Out:
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]
# WARNING: SliceWarning: Slice (slice(None, None, None), None) cannot be used on this 1-dimensional array's WCS.  If this is intentional, you  should use this <class 'spectral_cube.lower_dimensional_structures.Slice'>'s ``array``  or ``quantity`` attribute. [spectral_cube.lower_dimensional_structures]

# %%
psffn = '/orange/adamginsburg/ALMA_IMF/2017.1.01355.L/June2021Release/G012.80/B3/cleanest/G012.80_B3_uid___A001_X1296_X1fb_continuum_merged_12M_robust-0.5_selfcal7_finaliter.psf.tt0'
(psf_secondpeak, psf_secondpeak_loc, psf_sidelobe1_fraction, psf_firstpeak_integral, r_sidelobe,
 (rr, pixscale, cutout, beam, fullbeam, view, bmfit_residual)) = \
        get_psf_secondpeak(psffn, show_image=True, min_radial_extent=2.5*u.arcsec,
                   max_radial_extent=5*u.arcsec
                  )
rbin = (rr).astype(np.int)
radial_mean = ndimage.mean(cutout, labels=rbin, index=np.arange(100))
radial_mean2 = ndimage.mean(cutout**2, labels=rbin, index=np.arange(100))
first_min_ind = scipy.signal.find_peaks(-radial_mean2)[0][0]
first_sidelobe_ind = scipy.signal.find_peaks(radial_mean2 *
                      (np.arange(len(radial_mean2)) > first_min_ind))[0][0]
# Out:
# INFO: first_sidelobe_ind=15, first_min_ind = 13 [imstats]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /scratch/local/10336938/ipykernel_64866/2154556543.py in <module>
#       1 psffn = '/orange/adamginsburg/ALMA_IMF/2017.1.01355.L/June2021Release/G012.80/B3/cleanest/G012.80_B3_uid___A001_X1296_X1fb_continuum_merged_12M_robust-0.5_selfcal7_finaliter.psf.tt0'
# ----> 2 (psf_secondpeak, psf_secondpeak_loc, psf_sidelobe1_fraction, psf_firstpeak_integral, r_sidelobe,
#       3  (rr, pixscale, cutout, beam, fullbeam, view, bmfit_residual)) = \
#       4         get_psf_secondpeak(psffn, show_image=True, min_radial_extent=2.5*u.arcsec,
#       5                    max_radial_extent=5*u.arcsec
#
# ValueError: too many values to unpack (expected 6)

# %%
pl.imshow(cutout.value)

# %%
pl.figure(figsize=(12,6))
pl.rcParams['font.size'] = 14
pl.subplot(1,2,1)
pl.plot(rr.ravel(), cutout.ravel(), '.', markersize=3)
pl.plot(radial_mean)
pl.vlines([first_min_ind, first_sidelobe_ind], -0.1,0.15, linestyle=':', color='r')
pl.plot(rr[view].ravel(), bmfit_residual.ravel(), '.', markersize=2)
pl.plot([0,300], [0,0], 'k--')
pl.axis((0,50,-0.075,0.075))
pl.xlabel("Pixel Index")
pl.ylabel("PSF")

pl.subplot(1,2,2)
pl.plot(rr.ravel(), cutout.ravel()**2, '.', markersize=3)
pl.plot(radial_mean2)
pl.vlines([first_min_ind, first_sidelobe_ind], -0.1,0.15, linestyle=':', color='r')
pl.plot([0,300], [0,0], 'k--')
pl.axis((0,50,0.0,0.005))
pl.xlabel("Pixel Index")
pl.ylabel("PSF$^2$")
pl.tight_layout()

# %%
psffn = '/orange/adamginsburg/ALMA_IMF/2017.1.01355.L/June2021Release/G012.80/B3/cleanest/G012.80_B3_uid___A001_X1296_X1fb_continuum_merged_12M_robust-0.5_selfcal7_finaliter.psf.tt0'
(psf_secondpeak, psf_secondpeak_loc, psf_sidelobe1_fraction, epsilon, firstnull, (rr, pixscale, cutout, beam, view, bmfit_residual)) = \
        get_psf_secondpeak(psffn, show_image=True, min_radial_extent=2.5*u.arcsec,
                   max_radial_extent=5*u.arcsec
                  )
epsilon

# %%
pixscale

# %%
ax2=pl.gca()

ax2.set_title(field)
rr_inds = rr.ravel().argsort()
sorted_synth = (beam.array.ravel()/beam.array.max())[rr_inds]
pixscale = pixscale.to(u.arcsec)
ax2.plot(pixscale.value*rr.ravel()[rr_inds], sorted_synth, '-', label='Synth')
ax2.plot(pixscale.value*rr.ravel(), cutout.ravel()/cutout.max(), '.', label='Dirty', alpha=0.75, markersize=2)
ax2.set_xlim(0, firstnull.value*2)# rr[view].max())
ax2.text(firstnull.value*1.5, 0.9, f'$\epsilon={epsilon:0.2f}$')

# %%
pl.acorr

# %%
rr.ravel().argsort()
