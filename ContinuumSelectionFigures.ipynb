# %%
# %matplotlib inline

# %%
import pylab as pl

# %%
# %run /orange/adamginsburg/ALMA_IMF/reduction/analysis/continuum_selections.py
# Out:
# band B3 in figure 0
# Loop info:  band=3, fieldG008.67, muid={'member.uid___A001_X1296_X1c3': '7M', 'member.uid___A001_X1296_X1c1': '12Mshort', 'member.uid___A001_X1296_X1bf': '12Mlong'}, spw=1, spwn=0
# /orange/adamginsburg/ALMA_IMF/2017.1.01355.L/imaging_results/spectra/G008.67_B3_spw1_12M.image_mean.fits
# /orange/adamginsburg/ALMA_IMF/2017.1.01355.L/imaging_results/spectra/G008.67_B3_spw1_12M.image_mean.fits
# Loop info:  band=3, fieldG010.62, muid={'member.uid___A001_X1296_X1e5': '12Mlong', 'member.uid___A001_X1296_X1e7': '12Mshort', 'member.uid___A001_X1296_X1e9': '7M'}, spw=1, spwn=0
# /orange/adamginsburg/ALMA_IMF/2017.1.01355.L/imaging_results/spectra/G010.62_B3_spw1_12M.image_mean.fits
# /orange/adamginsburg/ALMA_IMF/2017.1.01355.L/imaging_results/spectra/G010.62_B3_spw1_12M.image_mean.fits
# Loop info:  band=3, fieldG012.80, muid={'member.uid___A001_X1296_X1f7': '12Mlong', 'member.uid___A001_X1296_X1f9': '12Mshort', 'member.uid___A001_X1296_X1fb': '7M'}, spw=1, spwn=0
# ...

# %%
pl.show()

# %%
pl.figure(0)

# %%
pl.figure(1)

# %%
pl.figure(2)

# %%
ls -d /orange/adamginsburg/ALMA_IMF/2017.1.01355.L/*ms

# %%
mkdir /orange/adamginsburg/ALMA_IMF/2017.1.01355.L/imaging_results/spectra/pngs/

# %%
widths = [fcov[key][1] - fcov[key][0] for key in fcov]
widths

# %%
width_ratios = np.array(widths) / min(widths)
width_ratios
# Out:
# array([1.46958027, 1.47310871, 1.4762021 , 1.        , 1.00085851,
#        2.47216206, 2.47512002, 8.36251869])

# %%
import matplotlib.gridspec as gridspec
gs = gridspec.GridSpec(1, nspw, width_ratios=width_ratios)

# %%
dir(gs[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_from_subplot_args',
#  '_gridspec',
#  '_layoutbox',
#  '_num2',
#  'colspan',
#  'get_geometry',
#  'get_gridspec',
#  'get_position',
#  'get_rows_columns',
#  'get_topmost_subplotspec',
#  'num1',
#  'num2',
#  'rowspan',
#  'subgridspec']
